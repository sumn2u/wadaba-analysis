# %%
import numpy as np
from scipy.stats import f_oneway

# Define metric data for each model with two experiments each
data = {
    "YOLO-11m": {
        "Accuracy": [0.9553, 0.9483],
        "Precision": [0.9803, 0.9814],
        "Recall": [0.9740, 0.9657],
        "F1-score": [0.9921, 0.9908]
    },
    "YOLO-10m": {
        "Accuracy": [0.8706, 0.7685],
        "Precision": [0.9161, 0.8101],
        "Recall": [0.9460, 0.9374],
        "F1-score": [0.9842, 0.9563]
    },
    "YOLO-11n": {
        "Accuracy": [0.9774, 0.9553],
        "Precision": [0.9933, 0.9803],
        "Recall": [0.9839, 0.9740],
        "F1-score": [0.9949, 0.9921]
    },
    "YOLO-10n": {
        "Accuracy": [0.8706, 0.9288],
        "Precision": [0.9161, 0.9494],
        "Recall": [0.9460, 0.9772],
        "F1-score": [0.9842, 0.9867]
    },
    "EfficientNetV2": {
        "Accuracy": [0.5324, 0.5325],
        "Precision": [0.1065, 0.1065],
        "Recall": [0.2000, 0.2000],
        "F1-score": [0.1390, 0.1390]
    },
    "ResNet50": {
        "Accuracy": [0.5524, 0.6100],
        "Precision": [0.2775, 0.2398],
        "Recall": [0.2230, 0.2999],
        "F1-score": [0.1817, 0.2614]
    },
    "MobileNet": {
        "Accuracy": [0.9225, 0.9538],
        "Precision": [0.7165, 0.9441],
        "Recall": [0.7197, 0.9058],
        "F1-score": [0.7123, 0.9226]
    },
    "Custom Model": {
        "Accuracy": [0.9364, 0.9641],
        "Precision": [0.9360, 0.9637],
        "Recall": [0.9363, 0.9640],
        "F1-score": [0.9356, 0.9638]
    }
}

# Perform ANOVA tests across all models for each metric
anova_results = {}
for metric in ["Accuracy", "Precision", "Recall", "F1-score"]:
    metric_values = [data[model][metric] for model in data]  # Extract metric values for all models
    anova_results[metric] = f_oneway(*metric_values)  # Perform ANOVA

# Print results
print("\n=== ANOVA Test Results ===")
for metric, result in anova_results.items():
    f_stat, p_val = result
    print(f"{metric} - F-statistic: {f_stat:.4f}, P-value: {p_val:.4f}")
    
    if p_val < 0.05:
        print(f"  🚀 Significant difference found in {metric} across models!")
    else:
        print(f"  ✅ No significant difference in {metric}.")
# Out:
# === ANOVA Test Results ===
# Accuracy - F-statistic: 50.6238, P-value: 0.0000
#   🚀 Significant difference found in Accuracy across models!
# Precision - F-statistic: 58.8684, P-value: 0.0000
#   🚀 Significant difference found in Precision across models!
# Recall - F-statistic: 82.4160, P-value: 0.0000
#   🚀 Significant difference found in Recall across models!
# F1-score - F-statistic: 80.4408, P-value: 0.0000
#   🚀 Significant difference found in F1-score across models!

# %%
import numpy as np
import pandas as pd
from scipy.stats import f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Model Names (Expanded with experiments)
models = [
    "YOLO-11m_1", "YOLO-11m_2", "YOLO-10m_1", "YOLO-10m_2", 
    "YOLO-11n_1", "YOLO-11n_2", "YOLO-10n_1", "YOLO-10n_2", 
    "EfficientNetV2_1", "EfficientNetV2_2", "ResNet50_1", "ResNet50_2", 
    "MobileNet_1", "MobileNet_2", "Custom_1", "Custom_2"
]

# Define metric data for each model (Expanded with experiments)
accuracy = [
    0.9553, 0.9483, 0.8706, 0.7685, 
    0.9774, 0.9553, 0.8706, 0.9288, 
    0.5324, 0.5325, 0.5524, 0.610, 
    0.9225, 0.9538, 0.9364, 0.9641
]

precision = [
    0.9803, 0.9814, 0.9161, 0.8101, 
    0.9933, 0.9803, 0.9161, 0.9494, 
    0.1065, 0.1065, 0.2775, 0.2398, 
    0.7165, 0.9441, 0.9360, 0.9637
]

recall = [
    0.9740, 0.9657, 0.9460, 0.9374, 
    0.9839, 0.9740, 0.9460, 0.9772, 
    0.2000, 0.2000, 0.2230, 0.2999, 
    0.7197, 0.9058, 0.9363, 0.9640
]

f1_score = [
    0.9921, 0.9908, 0.9842, 0.9563, 
    0.9949, 0.9921, 0.9842, 0.9867, 
    0.1390, 0.1390, 0.1817, 0.2614, 
    0.7123, 0.9226, 0.9356, 0.9638
]

# Convert to Pandas DataFrame
df = pd.DataFrame({
    "Model": models * 4, 
    "Metric": ["Accuracy"] * len(models) + ["Precision"] * len(models) + 
              ["Recall"] * len(models) + ["F1-score"] * len(models),
    "Value": accuracy + precision + recall + f1_score
})

# Perform Tukey’s HSD test
tukey_results = pairwise_tukeyhsd(df["Value"], df["Model"], alpha=0.05)

# Print results
print("\n=== Tukey’s HSD Test Results ===")
print(tukey_results)
# Out:
# === Tukey’s HSD Test Results ===
#           Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ========================================================================
#      group1           group2      meandiff p-adj   lower   upper  reject
# ------------------------------------------------------------------------
#         Custom_1         Custom_2   0.0278    1.0 -0.2281  0.2838  False
#         Custom_1 EfficientNetV2_1  -0.6916    0.0 -0.9475 -0.4357   True
#         Custom_1 EfficientNetV2_2  -0.6916    0.0 -0.9475 -0.4356   True
#         Custom_1      MobileNet_1  -0.1683 0.5732 -0.4243  0.0876  False
#         Custom_1      MobileNet_2  -0.0045    1.0 -0.2604  0.2514  False
#         Custom_1       ResNet50_1  -0.6274    0.0 -0.8834 -0.3715   True
#         Custom_1       ResNet50_2  -0.5833    0.0 -0.8392 -0.3274   True
#         Custom_1       YOLO-10m_1  -0.0068    1.0 -0.2628  0.2491  False
#         Custom_1       YOLO-10m_2   -0.068 0.9998 -0.3239  0.1879  False
#         Custom_1       YOLO-10n_1  -0.0068    1.0 -0.2628  0.2491  False
#         Custom_1       YOLO-10n_2   0.0244    1.0 -0.2315  0.2804  False
#         Custom_1       YOLO-11m_1   0.0393    1.0 -0.2166  0.2953  False
#         Custom_1       YOLO-11m_2   0.0355    1.0 -0.2205  0.2914  False
#         Custom_1       YOLO-11n_1   0.0513    1.0 -0.2046  0.3072  False
#         Custom_1       YOLO-11n_2   0.0393    1.0 -0.2166  0.2953  False
#         Custom_2 EfficientNetV2_1  -0.7194    0.0 -0.9754 -0.4635   True
#         Custom_2 EfficientNetV2_2  -0.7194    0.0 -0.9753 -0.4635   True
#         Custom_2      MobileNet_1  -0.1962 0.3207 -0.4521  0.0598  False
#         Custom_2      MobileNet_2  -0.0323    1.0 -0.2883  0.2236  False
#         Custom_2       ResNet50_1  -0.6552    0.0 -0.9112 -0.3993   True
#         Custom_2       ResNet50_2  -0.6111    0.0 -0.8671 -0.3552   True
#         Custom_2       YOLO-10m_1  -0.0347    1.0 -0.2906  0.2213  False
#         Custom_2       YOLO-10m_2  -0.0958 0.9912 -0.3518  0.1601  False
#         Custom_2       YOLO-10n_1  -0.0347    1.0 -0.2906  0.2213  False
#         Custom_2       YOLO-10n_2  -0.0034    1.0 -0.2593  0.2526  False
#         Custom_2       YOLO-11m_1   0.0115    1.0 -0.2444  0.2675  False
#         Custom_2       YOLO-11m_2   0.0077    1.0 -0.2483  0.2636  False
#         Custom_2       YOLO-11n_1   0.0235    1.0 -0.2325  0.2794  False
#         Custom_2       YOLO-11n_2   0.0115    1.0 -0.2444  0.2675  False
# EfficientNetV2_1 EfficientNetV2_2      0.0    1.0 -0.2559   0.256  False
# EfficientNetV2_1      MobileNet_1   0.5233    0.0  0.2673  0.7792   True
# EfficientNetV2_1      MobileNet_2   0.6871    0.0  0.4312   0.943   True
# EfficientNetV2_1       ResNet50_1   0.0642 0.9999 -0.1918  0.3201  False
# EfficientNetV2_1       ResNet50_2   0.1083 0.9731 -0.1476  0.3642  False
# EfficientNetV2_1       YOLO-10m_1   0.6848    0.0  0.4288  0.9407   True
# EfficientNetV2_1       YOLO-10m_2   0.6236    0.0  0.3677  0.8795   True
# EfficientNetV2_1       YOLO-10n_1   0.6848    0.0  0.4288  0.9407   True
# EfficientNetV2_1       YOLO-10n_2    0.716    0.0  0.4601   0.972   True
# EfficientNetV2_1       YOLO-11m_1    0.731    0.0   0.475  0.9869   True
# EfficientNetV2_1       YOLO-11m_2   0.7271    0.0  0.4711   0.983   True
# EfficientNetV2_1       YOLO-11n_1   0.7429    0.0   0.487  0.9988   True
# EfficientNetV2_1       YOLO-11n_2    0.731    0.0   0.475  0.9869   True
# EfficientNetV2_2      MobileNet_1   0.5232    0.0  0.2673  0.7792   True
# EfficientNetV2_2      MobileNet_2   0.6871    0.0  0.4311   0.943   True
# EfficientNetV2_2       ResNet50_1   0.0642 0.9999 -0.1918  0.3201  False
# EfficientNetV2_2       ResNet50_2   0.1083 0.9732 -0.1477  0.3642  False
# EfficientNetV2_2       YOLO-10m_1   0.6847    0.0  0.4288  0.9407   True
# EfficientNetV2_2       YOLO-10m_2   0.6236    0.0  0.3676  0.8795   True
# EfficientNetV2_2       YOLO-10n_1   0.6847    0.0  0.4288  0.9407   True
# EfficientNetV2_2       YOLO-10n_2    0.716    0.0  0.4601   0.972   True
# EfficientNetV2_2       YOLO-11m_1   0.7309    0.0   0.475  0.9869   True
# EfficientNetV2_2       YOLO-11m_2    0.727    0.0  0.4711   0.983   True
# EfficientNetV2_2       YOLO-11n_1   0.7429    0.0  0.4869  0.9988   True
# EfficientNetV2_2       YOLO-11n_2   0.7309    0.0   0.475  0.9869   True
#      MobileNet_1      MobileNet_2   0.1638  0.617 -0.0921  0.4198  False
#      MobileNet_1       ResNet50_1  -0.4591    0.0  -0.715 -0.2032   True
#      MobileNet_1       ResNet50_2   -0.415    0.0 -0.6709  -0.159   True
#      MobileNet_1       YOLO-10m_1   0.1615 0.6396 -0.0945  0.4174  False
#      MobileNet_1       YOLO-10m_2   0.1003 0.9864 -0.1556  0.3563  False
#      MobileNet_1       YOLO-10n_1   0.1615 0.6396 -0.0945  0.4174  False
#      MobileNet_1       YOLO-10n_2   0.1928 0.3479 -0.0632  0.4487  False
#      MobileNet_1       YOLO-11m_1   0.2077 0.2377 -0.0483  0.4636  False
#      MobileNet_1       YOLO-11m_2   0.2038 0.2638 -0.0521  0.4597  False
#      MobileNet_1       YOLO-11n_1   0.2196 0.1686 -0.0363  0.4756  False
#      MobileNet_1       YOLO-11n_2   0.2077 0.2377 -0.0483  0.4636  False
#      MobileNet_2       ResNet50_1  -0.6229    0.0 -0.8789  -0.367   True
#      MobileNet_2       ResNet50_2  -0.5788    0.0 -0.8347 -0.3229   True
#      MobileNet_2       YOLO-10m_1  -0.0023    1.0 -0.2583  0.2536  False
#      MobileNet_2       YOLO-10m_2  -0.0635 0.9999 -0.3194  0.1924  False
#      MobileNet_2       YOLO-10n_1  -0.0023    1.0 -0.2583  0.2536  False
#      MobileNet_2       YOLO-10n_2   0.0289    1.0  -0.227  0.2849  False
#      MobileNet_2       YOLO-11m_1   0.0438    1.0 -0.2121  0.2998  False
#      MobileNet_2       YOLO-11m_2     0.04    1.0  -0.216  0.2959  False
#      MobileNet_2       YOLO-11n_1   0.0558    1.0 -0.2001  0.3117  False
#      MobileNet_2       YOLO-11n_2   0.0438    1.0 -0.2121  0.2998  False
#       ResNet50_1       ResNet50_2   0.0441    1.0 -0.2118  0.3001  False
#       ResNet50_1       YOLO-10m_1   0.6206    0.0  0.3646  0.8765   True
#       ResNet50_1       YOLO-10m_2   0.5594    0.0  0.3035  0.8154   True
#       ResNet50_1       YOLO-10n_1   0.6206    0.0  0.3646  0.8765   True
#       ResNet50_1       YOLO-10n_2   0.6519    0.0  0.3959  0.9078   True
#       ResNet50_1       YOLO-11m_1   0.6668    0.0  0.4108  0.9227   True
#       ResNet50_1       YOLO-11m_2   0.6629    0.0   0.407  0.9188   True
#       ResNet50_1       YOLO-11n_1   0.6787    0.0  0.4228  0.9347   True
#       ResNet50_1       YOLO-11n_2   0.6668    0.0  0.4108  0.9227   True
#       ResNet50_2       YOLO-10m_1   0.5765    0.0  0.3205  0.8324   True
#       ResNet50_2       YOLO-10m_2   0.5153    0.0  0.2594  0.7712   True
#       ResNet50_2       YOLO-10n_1   0.5765    0.0  0.3205  0.8324   True
#       ResNet50_2       YOLO-10n_2   0.6078    0.0  0.3518  0.8637   True
#       ResNet50_2       YOLO-11m_1   0.6226    0.0  0.3667  0.8786   True
#       ResNet50_2       YOLO-11m_2   0.6188    0.0  0.3628  0.8747   True
#       ResNet50_2       YOLO-11n_1   0.6346    0.0  0.3787  0.8905   True
#       ResNet50_2       YOLO-11n_2   0.6226    0.0  0.3667  0.8786   True
#       YOLO-10m_1       YOLO-10m_2  -0.0612 0.9999 -0.3171  0.1948  False
#       YOLO-10m_1       YOLO-10n_1      0.0    1.0 -0.2559  0.2559  False
#       YOLO-10m_1       YOLO-10n_2   0.0313    1.0 -0.2246  0.2872  False
#       YOLO-10m_1       YOLO-11m_1   0.0462    1.0 -0.2097  0.3021  False
#       YOLO-10m_1       YOLO-11m_2   0.0423    1.0 -0.2136  0.2983  False
#       YOLO-10m_1       YOLO-11n_1   0.0581    1.0 -0.1978  0.3141  False
#       YOLO-10m_1       YOLO-11n_2   0.0462    1.0 -0.2097  0.3021  False
#       YOLO-10m_2       YOLO-10n_1   0.0612 0.9999 -0.1948  0.3171  False
#       YOLO-10m_2       YOLO-10n_2   0.0924 0.9938 -0.1635  0.3484  False
#       YOLO-10m_2       YOLO-11m_1   0.1073 0.9751 -0.1486  0.3633  False
#       YOLO-10m_2       YOLO-11m_2   0.1035  0.982 -0.1525  0.3594  False
#       YOLO-10m_2       YOLO-11n_1   0.1193 0.9411 -0.1366  0.3752  False
#       YOLO-10m_2       YOLO-11n_2   0.1073 0.9751 -0.1486  0.3633  False
#       YOLO-10n_1       YOLO-10n_2   0.0313    1.0 -0.2246  0.2872  False
#       YOLO-10n_1       YOLO-11m_1   0.0462    1.0 -0.2097  0.3021  False
#       YOLO-10n_1       YOLO-11m_2   0.0423    1.0 -0.2136  0.2983  False
#       YOLO-10n_1       YOLO-11n_1   0.0581    1.0 -0.1978  0.3141  False
#       YOLO-10n_1       YOLO-11n_2   0.0462    1.0 -0.2097  0.3021  False
#       YOLO-10n_2       YOLO-11m_1   0.0149    1.0  -0.241  0.2708  False
#       YOLO-10n_2       YOLO-11m_2    0.011    1.0 -0.2449   0.267  False
#       YOLO-10n_2       YOLO-11n_1   0.0269    1.0 -0.2291  0.2828  False
#       YOLO-10n_2       YOLO-11n_2   0.0149    1.0  -0.241  0.2708  False
#       YOLO-11m_1       YOLO-11m_2  -0.0039    1.0 -0.2598  0.2521  False
#       YOLO-11m_1       YOLO-11n_1    0.012    1.0  -0.244  0.2679  False
#       YOLO-11m_1       YOLO-11n_2      0.0    1.0 -0.2559  0.2559  False
#       YOLO-11m_2       YOLO-11n_1   0.0158    1.0 -0.2401  0.2718  False
#       YOLO-11m_2       YOLO-11n_2   0.0039    1.0 -0.2521  0.2598  False
#       YOLO-11n_1       YOLO-11n_2   -0.012    1.0 -0.2679   0.244  False
# ------------------------------------------------------------------------
